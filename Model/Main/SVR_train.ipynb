# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingGridSearchCV
import joblib

# %%
df = pd.read_csv("Dataset/Final/Remove-noise-not-outlier-and-fill-null.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = pd.read_csv("Dataset/Final/Remove-noise-not-outlier-and-fill-null.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dataset/Final/Remove-noise-not-outlier-and-fill-null.csv'

# %%
# Save'price_in_billion' individually
price_column = df['price_in_billion']
df = df.drop(['price_in_billion','ad_id','brand','url','grade','condition','price'], axis=1)

# Define columns that need encoded and scaled
columns_for_encoding = ['origin','car_model','exterior_color','interior_color','engine','transmission','drive_type','car_name']
columns_for_scaling = ['num_of_doors','seating_capacity','engine_capacity','fuel_consumption','mileage','year_of_manufacture']

# Apply StandardScaler to numerical features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[columns_for_scaling])

# Apply OneHotEncoder to categorical features
encoder = OneHotEncoder(sparse_output=False)
df_encoded = encoder.fit_transform(df[columns_for_encoding])


# Apply Truncated SVD to the one-hot encoded categorical features
n_components_svd = min(df_encoded.shape[1] - 1, 500)  # Adjust the number of components as necessary
svd = TruncatedSVD(n_components=n_components_svd, random_state=42)
df_svd = svd.fit_transform(df_encoded)

# Combine scaled numerical features and SVD-transformed categorical features
df_combined = np.hstack((df_scaled, df_svd))

X_train, X_test, y_train, y_test = train_test_split(df_combined, price_column, test_size=0.3, random_state=42)

# %%
#Define pipeline
pipeline = Pipeline(steps=[
    ('svr', SVR())
])

# %%
#Define hyperparameters of pipeline that need tuning and the range values of them
param_grid = {'svr__C': [10,20,50,100,200,300,400,500],  
              'svr__gamma': [0.001,0.01,0.1,1.0], 
              'svr__kernel': ['poly','rbf'],
              'svr__epsilon':[0.01,0.1,0.25,1.0,4.0,16.0,64.0,256.0],
             }

# %%
# Define the halving grid search with cross-validation
halving_grid_search = HalvingGridSearchCV(pipeline, param_grid, scoring="r2", cv=5, verbose=6, factor=3,error_score='raise')
halving_grid_search.fit(X_train, y_train)
# Out:
# n_iterations: 5
# n_required_iterations: 6
# n_possible_iterations: 5
# min_resources_: 88
# max_resources_: 21456
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 512
# n_resources: 88
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.116, test=-0.049) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.097, test=-0.076) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.063, test=-0.179) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.101, test=-0.062) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.078, test=-0.292) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.231, test=0.571) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.264, test=0.417) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.252, test=0.010) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.208, test=0.375) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.149, test=0.170) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.006, test=0.010) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.013, test=0.078) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.027, test=-0.159) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.042, test=0.098) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.025, test=-0.225) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.598, test=0.612) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.665, test=0.514) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.627, test=0.338) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.473, test=0.588) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.504, test=0.682) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.468) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.891) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.303) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.644) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.998, test=-0.297) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.340) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.406) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.995, test=0.804) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.992, test=0.590) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.468) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.891) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.303) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.644) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.890, test=-0.441) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.019) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.051) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.010) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.989, test=0.059) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.107, test=-0.031) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.120, test=-0.095) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.055, test=-0.170) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.098, test=-0.059) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.066, test=-0.241) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.229, test=0.545) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.271, test=0.411) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.226, test=-0.000) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.218, test=0.354) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.167, test=0.204) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.014, test=0.026) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.026, test=0.105) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.035, test=-0.160) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.041, test=0.105) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.018, test=-0.192) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.613, test=0.678) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.669, test=0.554) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.634, test=0.303) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.493, test=0.585) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.527, test=0.692) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.999, test=0.485) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.992, test=0.874) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.994, test=0.296) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.996, test=0.638) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.998, test=0.545) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.997, test=-0.351) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.993, test=0.358) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.994, test=0.413) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.992, test=0.816) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.991, test=0.583) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.999, test=0.485) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.992, test=0.874) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.994, test=0.296) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.996, test=0.638) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.998, test=0.545) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.891, test=-0.527) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.991, test=0.016) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.993, test=-0.040) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.996, test=0.003) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.987, test=0.048) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.094, test=-0.011) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.066, test=-0.052) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.047, test=-0.160) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.063, test=-0.031) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.068, test=-0.249) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.222, test=0.533) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.268, test=0.371) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.251, test=0.046) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.234, test=0.360) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.204, test=0.325) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.020, test=0.040) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.028, test=0.125) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.056, test=-0.141) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.008, test=0.133) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.008, test=-0.149) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.628, test=0.718) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.683, test=0.585) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.649, test=0.307) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.538, test=0.607) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.561, test=0.706) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.995, test=0.478) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.955, test=0.885) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.966, test=0.276) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.976, test=0.626) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.989, test=0.512) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.993, test=-0.474) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.962, test=0.376) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.969, test=0.416) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.974, test=0.825) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.985, test=0.571) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.995, test=0.478) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.955, test=0.885) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.966, test=0.276) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.976, test=0.626) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.989, test=0.512) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.889, test=-0.697) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.946, test=0.004) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.962, test=-0.020) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.974, test=-0.015) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=0.25, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.977, test=0.003) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.018, test=-0.226) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.075, test=-0.060) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.032, test=-0.020) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.018, test=-0.059) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.001, test=-0.025) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.220, test=0.227) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-0.002, test=0.139) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.062, test=0.159) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.091, test=0.129) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.162, test=0.125) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.097, test=-0.197) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.029, test=0.032) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.040, test=-0.003) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.003, test=-0.033) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.035, test=-0.038) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.655, test=0.511) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.235, test=0.363) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.569, test=0.519) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.457, test=0.673) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.505, test=0.549) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.917, test=-0.177) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.314, test=0.447) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.477, test=0.212) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.650, test=0.374) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=0.826, test=0.012) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.918, test=-1.785) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.320, test=0.014) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.471, test=0.306) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.674, test=0.579) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.843, test=0.215) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.917, test=-0.177) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.314, test=0.447) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.477, test=0.212) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.650, test=0.374) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=0.826, test=0.012) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.825, test=-2.115) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.246, test=-0.305) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.404, test=-0.020) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.626, test=-0.310) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=1.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=0.777, test=-0.723) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.576, test=-12.313) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-4.286, test=-5.486) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-2.075, test=-11.404) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-0.595, test=-13.556) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-4.634, test=-5.834) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-2.404, test=-13.747) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-0.530, test=-12.556) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-4.331, test=-5.538) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-2.178, test=-12.043) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-0.000, test=-9.485) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-4.817, test=-5.542) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-1.947, test=-12.487) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-0.178, test=-13.289) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-4.935, test=-6.247) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-2.314, test=-14.502) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-0.326, test=-17.191) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-5.080, test=-6.298) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-2.331, test=-14.656) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-0.178, test=-13.288) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-4.935, test=-6.248) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-2.314, test=-14.502) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-0.367, test=-18.800) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-4.798, test=-6.428) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=4.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-2.298, test=-15.142) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=16.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=64.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.001, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.01, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=0.1, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=poly;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-5.752, test=-82.188) total time=   0.0s
# [CV 2/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.000, test=-2.373) total time=   0.0s
# [CV 3/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-3.719, test=-1.014) total time=   0.0s
# [CV 4/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-8.280, test=-10.356) total time=   0.0s
# [CV 5/5] END svr__C=10, svr__epsilon=256.0, svr__gamma=1.0, svr__kernel=rbf;, score=(train=-6.867, test=-36.791) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.116, test=-0.049) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.097, test=-0.076) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.063, test=-0.179) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.101, test=-0.062) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.078, test=-0.292) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.380, test=0.694) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.330, test=0.452) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.333, test=0.075) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.274, test=0.463) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.001, svr__kernel=rbf;, score=(train=0.211, test=0.275) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.119, test=0.062) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.047, test=0.145) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.101, test=-0.147) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.007, test=0.245) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.018, test=-0.174) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.773, test=0.695) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.765, test=0.603) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.769, test=0.405) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.609, test=0.649) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.661, test=0.766) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.468) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.891) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.303) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.644) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=-0.335) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.340) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.406) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.826) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=1.000, test=0.574) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.468) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.891) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.303) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.644) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.721) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.019) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=-0.051) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.010) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=1.0, svr__kernel=rbf;, score=(train=1.000, test=0.059) total time=   0.0s
# [CV 1/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.107, test=-0.031) total time=   0.0s
# [CV 2/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.120, test=-0.094) total time=   0.0s
# [CV 3/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.055, test=-0.170) total time=   0.0s
# [CV 4/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.098, test=-0.059) total time=   0.0s
# [CV 5/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.001, svr__kernel=poly;, score=(train=-0.066, test=-0.241) total time=   0.0s
# ...
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.870, test=0.848) total time=   1.3s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.902, test=0.885) total time=   1.4s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.970, test=0.821) total time=   1.4s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.952, test=0.892) total time=   1.5s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.951, test=0.833) total time=   1.5s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.936, test=0.844) total time=   1.6s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.980, test=0.875) total time=   3.8s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.990, test=0.820) total time=   3.6s
# [CV 1/5] END svr__C=300, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.829, test=0.716) total time=   0.7s
# [CV 2/5] END svr__C=300, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.808, test=0.569) total time=   0.7s
# [CV 3/5] END svr__C=300, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.810, test=0.548) total time=   0.7s
# [CV 4/5] END svr__C=300, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.867, test=0.848) total time=   0.7s
# [CV 5/5] END svr__C=300, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.879, test=0.761) total time=   0.5s
# [CV 1/5] END svr__C=300, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.827, test=0.731) total time=   1.0s
# [CV 2/5] END svr__C=300, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.806, test=0.580) total time=   1.0s
# [CV 3/5] END svr__C=300, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.808, test=0.406) total time=   1.0s
# [CV 4/5] END svr__C=300, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.864, test=0.870) total time=   1.0s
# [CV 5/5] END svr__C=300, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.875, test=0.759) total time=   1.0s
# [CV 1/5] END svr__C=300, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.825, test=0.744) total time=   2.4s
# [CV 2/5] END svr__C=300, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.803, test=0.571) total time=   2.3s
# [CV 3/5] END svr__C=300, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.807, test=0.046) total time=   2.3s
# [CV 4/5] END svr__C=300, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.859, test=0.875) total time=   2.1s
# [CV 5/5] END svr__C=300, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.872, test=0.755) total time=   2.1s
# [CV 1/5] END svr__C=50, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.818, test=0.815) total time=   3.4s
# [CV 2/5] END svr__C=50, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.756, test=0.729) total time=   4.1s
# [CV 3/5] END svr__C=50, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.793, test=0.817) total time=   4.2s
# [CV 4/5] END svr__C=50, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.822, test=0.880) total time=   4.4s
# [CV 5/5] END svr__C=50, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.904, test=0.803) total time=   3.9s
# [CV 1/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.848, test=0.766) total time=   1.1s
# [CV 2/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.831, test=0.586) total time=   1.1s
# [CV 3/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.831, test=0.403) total time=   1.1s
# [CV 4/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.890, test=0.871) total time=   1.3s
# [CV 5/5] END svr__C=400, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.897, test=0.776) total time=   1.2s
# [CV 1/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.824, test=0.813) total time=   2.3s
# [CV 2/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.764, test=0.731) total time=   1.9s
# [CV 3/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.797, test=0.818) total time=   2.0s
# [CV 4/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.831, test=0.879) total time=   2.2s
# [CV 5/5] END svr__C=50, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.910, test=0.806) total time=   2.2s
# [CV 1/5] END svr__C=400, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.849, test=0.746) total time=   0.6s
# [CV 2/5] END svr__C=400, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.832, test=0.575) total time=   0.6s
# [CV 3/5] END svr__C=400, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.833, test=0.471) total time=   0.6s
# [CV 4/5] END svr__C=400, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.893, test=0.851) total time=   0.6s
# [CV 5/5] END svr__C=400, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.900, test=0.778) total time=   0.7s
# [CV 1/5] END svr__C=400, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.844, test=0.778) total time=   2.3s
# [CV 2/5] END svr__C=400, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.828, test=0.571) total time=   2.1s
# [CV 3/5] END svr__C=400, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.827, test=-0.027) total time=   2.5s
# [CV 4/5] END svr__C=400, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.886, test=0.875) total time=   2.2s
# [CV 5/5] END svr__C=400, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.894, test=0.774) total time=   2.6s
# [CV 1/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.863, test=0.763) total time=   0.7s
# [CV 2/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.849, test=0.576) total time=   0.6s
# [CV 3/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.852, test=0.366) total time=   0.6s
# [CV 4/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.907, test=0.844) total time=   0.6s
# [CV 5/5] END svr__C=500, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.916, test=0.787) total time=   0.6s
# [CV 1/5] END svr__C=50, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.833, test=0.802) total time=   1.0s
# [CV 2/5] END svr__C=50, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.773, test=0.724) total time=   1.1s
# [CV 3/5] END svr__C=50, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.799, test=0.812) total time=   1.1s
# [CV 4/5] END svr__C=50, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.839, test=0.870) total time=   1.1s
# [CV 5/5] END svr__C=50, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.915, test=0.809) total time=   1.1s
# [CV 1/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.863, test=0.788) total time=   1.0s
# [CV 2/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.848, test=0.597) total time=   1.1s
# [CV 3/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.851, test=0.318) total time=   1.1s
# [CV 4/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.905, test=0.866) total time=   1.1s
# [CV 5/5] END svr__C=500, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.914, test=0.790) total time=   1.1s
# [CV 1/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.858, test=0.798) total time=   2.0s
# [CV 2/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.845, test=0.584) total time=   2.5s
# [CV 3/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.845, test=-0.039) total time=   2.5s
# [CV 4/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.902, test=0.871) total time=   2.6s
# [CV 5/5] END svr__C=500, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=poly;, score=(train=0.911, test=0.789) total time=   2.4s
# [CV 1/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.862, test=0.817) total time=   1.3s
# [CV 2/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.812, test=0.740) total time=   1.5s
# [CV 3/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.832, test=0.823) total time=   1.6s
# [CV 4/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.886, test=0.876) total time=   1.3s
# [CV 5/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.935, test=0.816) total time=   1.6s
# [CV 1/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.857, test=0.827) total time=   5.4s
# [CV 2/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.804, test=0.732) total time=   5.9s
# [CV 3/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.829, test=0.829) total time=   5.0s
# [CV 4/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.873, test=0.895) total time=   5.0s
# [CV 5/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.932, test=0.815) total time=   4.7s
# [CV 1/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.860, test=0.825) total time=   2.6s
# [CV 2/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.808, test=0.732) total time=   2.6s
# [CV 3/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.832, test=0.826) total time=   2.5s
# [CV 4/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.880, test=0.887) total time=   2.5s
# [CV 5/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.935, test=0.816) total time=   2.7s
# ----------
# iter: 4
# n_candidates: 7
# n_resources: 7128
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.849, test=0.820) total time=   9.6s
# [CV 2/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.828, test=0.847) total time=   9.8s
# [CV 3/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.835, test=0.800) total time=  10.9s
# [CV 4/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.872, test=0.863) total time=  11.5s
# [CV 5/5] END svr__C=100, svr__epsilon=0.25, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.840, test=0.774) total time=  11.3s
# [CV 1/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.845, test=0.818) total time=  22.6s
# [CV 2/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.823, test=0.844) total time=  23.0s
# [CV 3/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.831, test=0.802) total time=  22.5s
# [CV 4/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.870, test=0.861) total time=  21.6s
# [CV 5/5] END svr__C=100, svr__epsilon=0.1, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.838, test=0.772) total time=  21.7s
# [CV 1/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.842, test=0.816) total time=  52.7s
# [CV 2/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.820, test=0.843) total time=  48.2s
# [CV 3/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.825, test=0.799) total time=  46.6s
# [CV 4/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.865, test=0.857) total time=  44.0s
# [CV 5/5] END svr__C=100, svr__epsilon=0.01, svr__gamma=0.01, svr__kernel=rbf;, score=(train=0.835, test=0.768) total time=  49.1s
# [CV 1/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.952, test=0.877) total time=  10.2s
# [CV 2/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.930, test=0.798) total time=   9.4s
# [CV 3/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.944, test=0.881) total time=   9.3s
# [CV 4/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.964, test=0.911) total time=   9.1s
# [CV 5/5] END svr__C=20, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.938, test=0.849) total time=   9.6s
# [CV 1/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.912, test=0.853) total time=   8.5s
# [CV 2/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.893, test=0.791) total time=   9.0s
# [CV 3/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.903, test=0.856) total time=   8.7s
# [CV 4/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.930, test=0.898) total time=   8.5s
# [CV 5/5] END svr__C=10, svr__epsilon=0.1, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.903, test=0.822) total time=   7.5s
# [CV 1/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.951, test=0.878) total time=  19.7s
# [CV 2/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.929, test=0.798) total time=  21.7s
# [CV 3/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.944, test=0.883) total time=  22.9s
# [CV 4/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.963, test=0.911) total time=  20.6s
# [CV 5/5] END svr__C=20, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.938, test=0.851) total time=  20.5s
# [CV 1/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.911, test=0.853) total time=  18.4s
# [CV 2/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.893, test=0.789) total time=  18.1s
# [CV 3/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.902, test=0.856) total time=  18.3s
# [CV 4/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.929, test=0.899) total time=  19.3s
# [CV 5/5] END svr__C=10, svr__epsilon=0.01, svr__gamma=0.1, svr__kernel=rbf;, score=(train=0.903, test=0.823) total time=  19.3s
# HalvingGridSearchCV(error_score='raise',
#                     estimator=Pipeline(steps=[('svr', SVR())]),
#                     param_grid={'svr__C': [10, 20, 50, 100, 200, 300, 400, 500],
#                                 'svr__epsilon': [0.01, 0.1, 0.25, 1.0, 4.0,
#                                                  16.0, 64.0, 256.0],
#                                 'svr__gamma': [0.001, 0.01, 0.1, 1.0],
#                                 'svr__kernel': ['poly', 'rbf']},
#                     scoring='r2', verbose=6)

# %%
best_params = halving_grid_search.best_params_
best_model = halving_grid_search.best_estimator_
best_score = halving_grid_search.best_score_

# %%
# Save the best model
joblib_file = "best_model.joblib"
joblib.dump(best_model, joblib_file)
print(f"Model saved to {joblib_file}")

# Load the model from the file
loaded_model = joblib.load(joblib_file)
# Out:
# Model saved to best_model.joblib

# %%
y_pred = loaded_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Best parameters: {best_params}")
print(f"Best scores: {best_score}")
print(f"Test MSE: {mse}")
print(f"Model score: {best_model.score(X_test, y_test)}")
# Out:
# Best parameters: {'svr__C': 20, 'svr__epsilon': 0.01, 'svr__gamma': 0.1, 'svr__kernel': 'rbf'}
# Best scores: 0.8639279857761399
# Test MSE: 0.6157878085505033
# Model score: 0.851871086940417
